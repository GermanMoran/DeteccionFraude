# %%
from pycaret.classification import *
from pycaret.datasets import get_data
import pandas as pd

# %%
# load the dataset from pycaret
# Cargue de datos
dataset = pd.read_csv("EVERTEC_DS.csv")

# %%
dataset.head(5)
# Out:
#       ID_TRX             S_PAN   S_ENCRYPTED_PAN  F_AMOUNT_TRANSACTION  \
# 0  508924809  488245******4567  1000065275814567                   5.4
# 1  509028097  410443******1014  1000126292771014                3350.0
# 2  511351088  434527******5015  1000007433745015                  10.8
# 3  515833505  410443******0018  1000126530570018                4960.8
# 4  519145453  478787******2328  1000020382542328               40250.0
#
#    N_CURRENCY_CODE_TRANSACTION  F_DOLLAR_AMOUNT  N_TRANSMISSION_DATE_AND_TIME  \
# 0                          840            5.388                20201001190732
# 1                          188            5.570                20201001194719
# 2                          840           10.800                20201002095534
# 3                          188            8.280                20201004101419
# 4                          188           67.177                20201005173241
#
#    N_MERCHANT_TYPE  N_ACQ_INSTITUTION_COUNTRY_CODE  N_ENTRY_MODE  \
# 0             7372                             840            10
# 1             4121                             372           102
# 2             4816                             840            10
# 3             4814                             188            10
# 4             5661                             188            10
#
#    N_POINT_OF_SERV_COND_CODE   S_MERCHANT_LEGAL_NAME  FRAUDE
# 0                         59  GOOGLE *GSUITE_inversi       0
# 1                         59   UBR* PENDING.UBER.COM       0
# 2                         59  Google LLC GSUITE_iyta       0
# 3                         59                   RAPPI       0
# 4                         59             FLEXI SHOES       0

# %%
# 80% training - 20% testing
data = dataset.sample(frac=0.8, random_state=123)
data_unseen = dataset.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (23392, 13)
# Unseen Data For Predictions (5848, 13)

# %% [markdown]
# # Procesamiento

# %%
# initialize setup

model_cl = setup(data = data, target = 'FRAUDE', 
                   session_id=123)
# Out:
# <style type="text/css">
# #T_1bcfa_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1bcfa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bcfa_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1bcfa_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bcfa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bcfa_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1bcfa_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1bcfa_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1bcfa_row1_col1" class="data row1 col1" >FRAUDE</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1bcfa_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_1bcfa_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1bcfa_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_1bcfa_row3_col1" class="data row3 col1" >(23392, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1bcfa_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_1bcfa_row4_col1" class="data row4 col1" >(23392, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1bcfa_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_1bcfa_row5_col1" class="data row5 col1" >(16374, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1bcfa_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_1bcfa_row6_col1" class="data row6 col1" >(7018, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1bcfa_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_1bcfa_row7_col1" class="data row7 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1bcfa_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_1bcfa_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1bcfa_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_1bcfa_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1bcfa_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_1bcfa_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1bcfa_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_1bcfa_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1bcfa_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_1bcfa_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1bcfa_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_1bcfa_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1bcfa_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_1bcfa_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1bcfa_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_1bcfa_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1bcfa_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_1bcfa_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1bcfa_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_1bcfa_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1bcfa_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_1bcfa_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1bcfa_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_1bcfa_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1bcfa_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_1bcfa_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1bcfa_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1bcfa_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_1bcfa_row21_col1" class="data row21 col1" >038e</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Entrenamiento de modelos

# %%
best_model = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             11:02:11
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_1d083 th {
#   text-align: left;
# }
# #T_1d083_row0_col0, #T_1d083_row0_col3, #T_1d083_row0_col4, #T_1d083_row1_col0, #T_1d083_row1_col1, #T_1d083_row1_col2, #T_1d083_row1_col3, #T_1d083_row1_col4, #T_1d083_row1_col5, #T_1d083_row1_col6, #T_1d083_row1_col7, #T_1d083_row2_col0, #T_1d083_row2_col1, #T_1d083_row2_col2, #T_1d083_row2_col3, #T_1d083_row2_col4, #T_1d083_row2_col5,
level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_1d083_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_1d083_row1_col1" class="data row1 col1" >0.9447</td>
#       <td id="T_1d083_row1_col2" class="data row1 col2" >0.9591</td>
#       <td id="T_1d083_row1_col3" class="data row1 col3" >0.8108</td>
#       <td id="T_1d083_row1_col4" class="data row1 col4" >0.9012</td>
#       <td id="T_1d083_row1_col5" class="data row1 col5" >0.8535</td>
#       <td id="T_1d083_row1_col6" class="data row1 col6" >0.8195</td>
#       <td id="T_1d083_row1_col7" class="data row1 col7" >0.8213</td>
#       <td id="T_1d083_row1_col8" class="data row1 col8" >0.5640</td>
#     </tr>
#     <tr>
#       <th id="T_1d083_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_1d083_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_1d083_row2_col1" class="data row2 col1" >0.9429</td>
#       <td id="T_1d083_row2_col2" class="data row2 col2" >0.9482</td>
#       <td id="T_1d083_row2_col3" class="data row2 col3" >0.7672</td>
#       <td id="T_1d083_row2_col4" class="data row2 col4" >0.9338</td>
#       <td id="T_1d083_row2_col5" class="data row2 col5" >0.8422</td>
#       <td id="T_1d083_row2_col6" class="data row2 col6" >0.8078</td>
#       <td id="T_1d083_row2_col7" class="data row2 col7" >0.8137</td>
#       <td id="T_1d083_row2_col8" class="data row2 col8" >0.1200</td>
#     </tr>
#     <tr>
#       <th id="T_1d083_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_1d083_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_1d083_row3_col1" class="data row3 col1" >0.9397</td>
#       <td id="T_1d083_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_1d083_row3_col3" class="data row3 col3" >0.7436</td>
#       <td id="T_1d083_row3_col4" class="data row3 col4" >0.9405</td>
#       <td id="T_1d083_row3_col5" class="data row3 col5" >0.8303</td>
#       <td id="T_1d083_row3_col6" class="data row3 col6" >0.7942</td>
#       <td id="T_1d083_row3_col7" class="data row3 col7" >0.8025</td>
#       <td id="T_1d083_row3_col8" class="data row3 col8" >0.1010</td>
#     </tr>
#     <tr>
#       <th id="T_1d083_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_1d083_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_1d083_row4_col1" class="data row4 col1" >0.9395</td>
#       <td id="T_1d083_row4_col2" class="data row4 col2" >0.9513</td>
#       <td id="T_1d083_row4_col3" class="data row4 col3" >0.8136</td>
#       <td id="T_1d083_row4_col4" class="data row4 col4" >0.8743</td>
#       <td id="T_1d083_row4_col5" class="data row4 col5" >0.8426</td>
#       <td id="T_1d083_row4_col6" class="data row4 col6" >0.8052</td>
#       <td id="T_1d083_row4_col7" class="data row4 col7" >0.8062</td>
#       <td id="T_1d083_row4_col8" class="data row4 col8" >1.5850</td>
#     </tr>
#     <tr>
#       <th id="T_1d083_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_1d083_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1d083_row5_col1" class="data row5 col1" >0.9307</td>
#       <td id="T_1d083_row5_col2" class="data row5 col2" >0.9521</td>
#       <td id="T_1d083_row5_col3" class="data row5 col3" >0.8354</td>
#       <td id="T_1d083_row5_col4" class="data row5 col4" >0.8229</td>
#       <td id="T_1d083_row5_col5" class="data row5 col5" >0.8280</td>
#       <td id="T_1d083_row5_col6" class="data row5 col6" >0.7847</td>
#       <td id="T_1d083_row5_col7" class="data row5 col7" >0.7855</td

# %%
# se muestra el mejor modelo obtenido despues de la validación cruzada (k-folders = 10)
print(best_model)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      n_estimators=100, n_jobs=-1, oob_score=False,
#                      random_state=123, verbose=0, warm_start=False)

# %%
# 
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
